# %% [markdown]
# ## Assignment 3: Web Scraping
#
# For this assignment, you are required to scrape data from e-commerce or other websites such as [Lelong](http://www.lelong.com.my), [Lazada](http://www.lazada.com.my/), [Mudah](http://www.mudah.my/), [iProperty](https://www.iproperty.com.my/), [Booking](http://www.booking.com), [Expedia](https://www.expedia.com.my/) etc.
#
# You are required to fork this Jupyter Notebook from my Github [here](https://github.com/kuanhoong/EDS-Assignment3 ) and then scrape the latest 1000 items from one of the website mentioned above. The scraped data should include:
#
# * Product Name/Product Title
# * Amount/Price
# * Brand
# * Comments/Reviews
# * Number of views
#
# In addition, you are required to export the scraped data to dataframe format and also save a copy in csv format. Upon successful extracting data to dataframe, you are required to do a data analysis on the data.
#
# Your analysis should provide answers to the following questions:
# * What do you think is interesting about this data? Tell a story about some interesting thing you have discovered by looking at the data.
# * Visualize your data with matplotlib or with folium library package.
#
# For example, you might consider whether there is a difference in pricings at different times doing the day or city, or whether other factors that influnced the pricings etc. Another thing you might consider is whether there is a relationship between the pricing and number of reviews or comments.
#
# Show your analysis workflow in your Jupyter notebook.
#
# The final submission should be pushed back to your respective Github account.

# %% [markdown]
# ### Folium
#
# [Folium](https://github.com/python-visualization/folium) makes it easy to visualize data that's been manipulated in Python on an interactive Leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing Vincent/Vega visualizations as markers on the map.

# %%
import pandas as pd
import re
import numpy as np
import folium
import matplotlib.pyplot as plt
# %matplotlib inline
from bs4 import BeautifulSoup
import requests

# %%
mapit = None
latlon = [ (3.144473, 101.708722), (3.144473, 101.708722),(3.135732, 101.686989)]
for coord in latlon:
    mapit = folium.Map( location=[ coord[0], coord[1] ] )
    folium.Marker([3.144473, 101.708722], icon=folium.Icon(color='blue',icon='star'), popup='Federal Hotel').add_to(mapit)
    folium.Marker([3.156374, 101.714579], icon=folium.Icon(color='green',icon='info-sign') , popup='Mandarin Oriental').add_to(mapit)
    folium.Marker([3.135732, 101.686989], icon=folium.Icon(color='red',icon='star') , popup='Le Meridien').add_to(mapit)
mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# scrape from lelong

# find the pattern for the first page
url = 'https://www.lelong.com.my/catalog/all/list?TheKeyword=macbook+pro&D='

# write a loop to scrape from page 1 to the last page

product_name=[]
for page in range(1,19):
    url_page = url+str(page)
    scrape = requests.get(url_page)
    soup = BeautifulSoup(scrape.content, 'lxml')
    link = soup.find_all('div',{'class':'item','class':'summary'})
    length = len(link)
    for i in range(0,length):
        name = link[i].a.get('title')
        product_name.append(name)

# %%
# write to csv
# convert the list to a pandas dataframe

df = pd.DataFrame({'name':product_name})
df
#df.to_csv('output.csv', index=False)
# Out:
#                                                    name
# 0     â
#  Urban Armor Gear UAG MacBook Pro 4th W/WO ...
# 1     NEW MacBook Pro 13 13.3 A1706 A1708 Matte Fros...
# 2     APPLE MacBook Pro 13 13.3 A1278 Matte Frosted ...
# 3     MacBook Pro Retina 13 A1502 A1425 Matte Froste...
# 4     NEW ORIGINAL Apple MacBook Pro 13'Unibody A127...
# 5     Thunderbolt Mini Displayport DP to VGA Adapter...
# 6     Genuine Apple 60W MagSafe Power Adapter Charge...
# 7     Apple 60W MagSafe 2 Power Adapter (for MacBook...
# 8     Apple 85W MagSafe 2 Power Adapter (for MacBook...
# 9     Apple 85W MagSafe Power Adapter (for 15- and 1...
# 10    MacBook Pro Retina 13 13.3 A1502 A1425 Matte F...
# 11    Apple 13-inch MacBook Pro with Touch Bar 3.1GH...
# 12    Apple 13-inch MacBook Pro with Touch Bar 3.1GH...
# 13    Apple 13-inch MacBook Pro 2.3GHz Dual-core i5 ...
# 14    Apple 13-inch MacBook Pro 2.3GHz Dual-core i5 ...
# 15    18Pcs Opening Tools Repair Kit For Smartphone ...
# 16    STM Dux 13 Inch MacBook Pro Retina 12 Hardshel...
# 17    STM Dux 13 Inch Macbook Pro Retina 12 Hardshel...
# 18    Genuine Apple 85W MagSafe 2 Power Adapter Char...
# 19    MacBook Pro 13 13.3 A1278 Matte Frosted Hard C...
# 20    MacBook Air Pro 13 13.3 MOSHI MUSE Microfiber ...
# 21    MacBook Pro Retina 15 15.4 A1398 Matte Frosted...
# 22    MacBook Pro Retina 13 13.3 A1502 A1425 Matte F...
# 23    Think Tank Photo My 2nd Brain 13-fit a MacBook...
# 24    Apple Macbook Pro 13' Monocozzi Lucid Matt Tra...
# 25    Apple MacBook Pro 13 i5 2.4GHz 1TB 6Gb Ram Not...
# 26    APPLE MACBOOK Pro MPXR2ZP/A 13.3" NB SIL (i5 2...
# 27    MacBook Air 11.6 12 13.3 15 Pro Crystal Case C...
# 28    Thunderbolt Mini Displayport DP to VGA Adapter...
# 29    Soft Keyboard Protector Cover Skin for MacBook...
# ...                                                 ...
# 1002         New Battery APPLE Macbook PRO A1286 Bateri
# 1003               New Battery Macbook PRO A1278 Bateri
# 1004         New Battery APPLE Macbook PRO A1278 Bateri
# 1005  New Adapter APPLE Macbook PRO W893808J66H Charger
# 1006         New Adapter APPLE Macbook Pro 2010 Charger
# 1007  NEW ORIGINAL Battery Apple MacBook Pro 15" A12...
# 1008  Nums Smart Ultra-thin Keyboard Keypad Trackpad...
# 1009  Apple MacBook Pro 13' with Retina Display 256G...
# 1010  Apple MacBook Pro 13' with Retina Display 512G...
# 1011        New Adapter APPLE Macbook PRO A1398 Charger
# 1012        New Adapter APPLE Macbook PRO A1466 Charger
# 1013              New Adapter Macbook PRO A1502 Charger
# 1014  NEW ORIGINAL -  Apple Macbook Air Pro Unibody ...
# 1015  Thunderbolt Mini Displayport DP to VGA Adapter...
# 1016  MacBook Air Pro Retina Candy Color Translucent...
# 1017  Think Tank Photo My 2nd Brain 15-fit MacBook P...
# 1018  Apple Macbook Pro 13" A1278 2009 2010 2011 Mid...
# 1019  Apple MacBook Pro 13' Unibody A1322 A1278 batt...
# 1020  MacBook Pro 13" New A1706 15" A1707 Clear Soft...
# 1021  Thunderbolt Mini Displayport DP to VGA Adapter...
# 1022         New Battery APPLE Macbook PRO A1286 Bateri
# 1023         New Battery APPLE Macbook PRO 2010  Bateri
# 1024         New Battery APPLE Macbook PRO A1278 Bateri
# 1025               New Battery Macbook Pro A1286 Bateri
# 1026          New Battery APPLE Macbook PRO 2009 Bateri
# 1027         New Battery APPLE Macbook PRO A1161 Bateri
# 1028         New Battery APPLE Macbook Pro A1278 Bateri
# 1029        New Adapter APPLE Macbook PRO A1502 Charger
# 1030  Thunderbolt Mini Displayport DP to VGA Adapter...
# 1031  Apple MacBook Pro 13 13.3 A1278 Transparent Cr...
#
# [1032 rows x 1 columns]
